# %% [markdown]
# # Hugging Face Transformers 🤗
#
# The Hugging Face transformers package is an immensely popular Python library providing pretrained models that are extraordinarily useful for a variety of natural language processing (NLP) tasks. It previously supported only PyTorch, but, as of late 2019, TensorFlow 2 is supported as well. While the library can be used for many tasks from Natural Language Inference (NLI) to Question-Answering, text classification remains one of the most popular and practical use cases.
#
# Transformers (formerly known as pytorch-transformers and pytorch-pretrained-bert) provides general-purpose architectures (BERT, GPT-2, RoBERTa, XLM, DistilBert, XLNet…) for Natural Language Understanding (NLU) and Natural Language Generation (NLG) with over 32+ pretrained models in 100+ languages and deep interoperability between Jax, PyTorch and TensorFlow.
#
# https://huggingface.co/transformers/

# %%
from transformers import pipeline
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# # Text Generation

# %%
generator = pipeline('text-generation')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">No model was supplied, defaulted to gpt2 (https://huggingface.co/gpt2)
# Downloading:   0%|          | 0.00/665 [00:00&lt;?, ?B/s]
# Downloading:   0%|          | 0.00/523M [00:00&lt;?, ?B/s]
# Downloading:   0%|          | 0.00/0.99M [00:00&lt;?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00&lt;?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00&lt;?, ?B/s]
# </div>

# %%
generator("Adam and Natalie are good friends.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Out[3]: [{&#39;generated_text&#39;: &#39;Adam and Natalie are good friends. They say they are the only ones on earth who have a relationship with each other and that she is in love with them but that is only in season 2. However, Natalie, once again, is her only friend&#39;}]</div>

# %%
generator("Since I have joined Queens University.")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Out[4]: [{&#39;generated_text&#39;: &#34;Since I have joined Queens University.\n\nMy new title is Dr. Lianne. I am an academic with a history. The history of my school is complete. I&#39;m a natural history teacher for over 20 years.\n\nMy name&#34;}]</div>

# %%
generator("Canada is a country.....")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Out[5]: [{&#39;generated_text&#39;: &#39;Canada is a country.....the land of the free.... (This quote was originally posted on http://www.nytimes.com/2007/05/11/opinion/economy.index.html ). It seems a different situation now.&#39;}]</div>
